# %%
import pandas as pd
import os

pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 1000)

# %%
pwd = os.getcwd()
df = pd.read_csv(pwd + "\\data\\2023_raw_data.txt")
df.columns = df.iloc[0]
df.drop(0, inplace=True, axis=0)
clist = ['Rank', 'Player', 'Team', 'Age', 'Position', 'Games', 'Games_started', 'RecTargets', 'Receptions', 'RecYard', 'Yards/Rec', 'RecTD',
         'Rec_first_down', 'RecSucc%', 'RecLong', 'Rec_per_game', 'RecYard_per_game', 'Catch%', 'Yards_per_target', 'RushAtt', 'RushYard', 'RushTD',
         'Rush_first_down', 'RushSucc%', 'RushLong', 'RushYard_per_attempt', 'RushYard_per_game', 'Rush_att_per_game', 'Touches_year',
         'Yards_per_touch', 'Yards_from_scrim', 'Fumbles', 'Touchdowns', 'Key']
df.columns = clist
df = df.fillna(0)

# %%
df[df['Position'] == 'QB']
# Out:
#     Rank                    Player Team Age Position Games Games_started  \
# 82    82           Lamar Jackson*+  BAL  26       QB    16            16
# 98    98               Taysom Hill  NOR  33       QB    16             7
# 104  104             Justin Fields  CHI  24       QB    13            13
# 116  116              Jalen Hurts*  PHI  25       QB    17            17
# 139  139                Josh Allen  BUF  27       QB    17            17
# 175  175          Patrick Mahomes*  KAN  28       QB    16            16
# 189  189            Russell Wilson  DEN  35       QB    15            15
# 190  190           Trevor Lawrence  JAX  24       QB    16            16
# 213  213                Sam Howell  WAS  23       QB    17            17
# 221  221               Bryce Young  CAR  22       QB    16            16
# 227  227               Jordan Love  GNB  25       QB    17            17
# 231  231              Kyler Murray  ARI  26       QB     8             8
# ...
